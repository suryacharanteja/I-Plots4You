# %% [markdown]
# # Basic plots

# %% [markdown]
# ### Plot(x, y)

# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
plt.style.use('_mpl-gallery')

# let us make up a data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# let us plot
fig, ax = plt.subplots()
ax.plot(x, y, linewidth=2.5)


ax.set(xlim=(0, 8), xticks=np.arange(1, 8), ylim=(0, 8), yticks=(1, 8))
plt.show()

# %% [markdown]
# ### scatter(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make the data
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, len(x))
# size and color:
sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

# plot
fig, ax = plt.subplots()

ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
print(y)
# Out:
# [ 1.95242972  2.5740136   5.25048993  3.67897327  2.4623273   3.53993856
#   5.49011253  7.95222157  1.51175334  2.74716618  2.39246781 -0.83816635
#   2.15241596  1.95224848  6.24795592  3.73617153  0.75342911  5.2933509
#   3.28745848  0.51371793  2.80670072  2.82281124  2.2522354   4.05942763]

# %% [markdown]
# ### bar(x, height)

# %%
plt.style.use('_mpl-gallery')

# make the data
np.random.seed(3)

x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))


# let us plot a bargraph
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)


ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
print(y)
# Out:
# [4.75398951 5.54073911 3.45452369 4.55413803 6.46473477 6.48146544
#  2.62792655 3.03621439]

# %% [markdown]
# ### stem(x, y)

# %%
plt.style.use('_mpl-gallery')

# make the data
np.random.seed(3)

x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))



# let us plot the stem
fig, ax = plt.subplots()


ax.stem(x, y)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
print(y)
# Out:
# [4.75398951 5.54073911 3.45452369 4.55413803 6.46473477 6.48146544
#  2.62792655 3.03621439]

# %% [markdown]
# ### step(x, y)

# %%
plt.style.use('_mpl-gallery')

# make the data
np.random.seed(3)

x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))



# let us plot the step
fig, ax = plt.subplots()


ax.step(x, y, linewidth=2.5)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
print(x)
# Out:
# [0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5]

# %%
print(y)
# Out:
# [4.75398951 5.54073911 3.45452369 4.55413803 6.46473477 6.48146544
#  2.62792655 3.03621439]

# %% [markdown]
# ### fillbetween(x, y1, y2)

# %%
plt.style.use('_mpl-gallery')

# make the data
np.random.seed(1)

x = np.linspace(0, 8, 16)

y1 = 3 + 4*x/8 + np.random.uniform(0.0, 0.5, len(x))

y2 = 3 + 2*x/8 + np.random.uniform(0.0, 0.5, len(x))


# let us plot 
fig, ax = plt.subplots()


ax.fill_between(x, y1, y2, alpha=0.5, linewidth=0)
ax.plot(x, (y1+y2)/2, linewidth=2)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
print(x)
# Out:
# [0.         0.53333333 1.06666667 1.6        2.13333333 2.66666667
#  3.2        3.73333333 4.26666667 4.8        5.33333333 5.86666667
#  6.4        6.93333333 7.46666667 8.        ]

# %%
print(y1)
# Out:
# [3.208511   3.62682891 3.53339052 3.95116629 4.14004461 4.37950263
#  4.69313011 5.03944703 5.33171707 5.66940837 5.87626392 6.27594308
#  6.30222612 6.90572538 6.74702713 7.33523376]

# %%
print(y2)
# Out:
# [3.2086524  3.41267825 3.33686014 3.49905074 3.93370562 4.15079745
#  3.95671209 4.27949464 4.50486124 4.64730333 4.37585544 4.48619406
#  4.68491521 5.17240459 4.91584008 5.21055381]

# %% [markdown]
# ### stackplot(x, y)

# %%
plt.style.use('_mpl-gallery')

# make the data
x = np.arange(0, 10, 2)

y1 = [1, 1.25, 2, 2.75, 3]
y2 = [1, 1, 1, 1, 1]
y3 = [2, 1, 2, 1, 2]

y = np.vstack([y1, y2, y3])

# it is time plot
fig, ax = plt.subplots()

ax.stackplot(x, y)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
print(x)
# Out:
# [0 2 4 6 8]

# %%
print(y)
# Out:
# [[1.   1.25 2.   2.75 3.  ]
#  [1.   1.   1.   1.   1.  ]
#  [2.   1.   2.   1.   2.  ]]

# %%
y.ndim
# Out:
# 2

# %%
y.size
# Out:
# 15

# %% [markdown]
# # Part2: Plots of arrays and fields

# %% [markdown]
# ### imshow(Z)

# %%
plt.style.use('_mpl-gallery')


# make up our data
X, Y = np.meshgrid(np.linspace(-3, 3, 16), np.linspace(-3, 3, 16))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)


# it is time to plot
fig, ax = plt.subplots()

ax.imshow(Z)

plt.show()

# %% [markdown]
# ### pcolormesh(X, Y, Z)

# %%
plt.style.use('_mpl-gallery-nogrid')


# make up our data
x = [-3, -2, -1.6, -1.2, -0.8, -0.5, -0.2, -0.1, 0.3, 0.5, 0.8, 1.1, 1.5, 1.9, 2.3, 3]

X, Y = np.meshgrid(x, np.linspace(-3, 3, 128))

Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)

# it is time plot
fig, ax = plt.subplots()

ax.pcolormesh(X, Y, Z, vmin=-0.5, vmax=1.0)

plt.show()

# %%
print(x)
# Out:
# [-3, -2, -1.6, -1.2, -0.8, -0.5, -0.2, -0.1, 0.3, 0.5, 0.8, 1.1, 1.5, 1.9, 2.3, 3]

# %%
print(Y)
# Out:
# [[-3.         -3.         -3.         ... -3.         -3.
#   -3.        ]
#  [-2.95275591 -2.95275591 -2.95275591 ... -2.95275591 -2.95275591
#   -2.95275591]
#  [-2.90551181 -2.90551181 -2.90551181 ... -2.90551181 -2.90551181
#   -2.90551181]
#  ...
#  [ 2.90551181  2.90551181  2.90551181 ...  2.90551181  2.90551181
#    2.90551181]
#  [ 2.95275591  2.95275591  2.95275591 ...  2.95275591  2.95275591
#    2.95275591]
#  [ 3.          3.          3.         ...  3.          3.
#    3.        ]]

# %%
print(Z)
Z.ndim
# Out:
# [[-4.07401958e-06 -1.28838776e-04 -3.40447963e-04 ... -7.30792916e-06
#    2.31542946e-05  3.28206063e-06]
#  [-5.37177167e-06 -1.66920881e-04 -4.35143479e-04 ... -4.12812728e-06
#    3.17088820e-05  4.37328135e-06]
#  [-7.05226182e-06 -2.15342980e-04 -5.53624014e-04 ...  1.64873796e-06
#    4.31415919e-05  5.80010944e-06]
#  ...
#  [-5.74689051e-06 -2.16086999e-05  2.64069449e-04 ...  2.87790548e-04
#    9.64709787e-05  7.10548074e-06]
#  [-4.33292917e-06 -1.27429828e-05  2.15594531e-04 ...  2.23589667e-04
#    7.41495528e-05  5.41212386e-06]
#  [-3.25160068e-06 -6.78098822e-06  1.74720832e-04 ...  1.72969079e-04
#    5.67532375e-05  4.10447954e-06]]
# 2

# %% [markdown]
# ### contour(X, Y, Z)

# %%
plt.style.use('_mpl-gallery-nogrid')


# let us make data for our contour
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256) )
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)

levels = np.linspace(np.min(Z), np.max(Z), 7)

# plot the contour
fig, ax = plt.subplots()

ax.contour(X, Y, Z, levels=levels)

plt.show()

# %%
print(levels)
# Out:
# [-0.6863404  -0.39579962 -0.10525883  0.18528195  0.47582273  0.76636351
#   1.0569043 ]

# %% [markdown]
# ### contourf(X, Y, Z)

# %%
plt.style.use('_mpl-gallery-nogrid')


# let us make data for our contour
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256) )
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)

levels = np.linspace(np.min(Z), np.max(Z), 7)

# plot the contourf
fig, ax = plt.subplots()

ax.contourf(X, Y, Z, levels=levels)

plt.show()

# %% [markdown]
# #### barbs(X, Y, U, V)

# %%
barbs([X, Y], U, V, [C], **kw)

# %%
plt.style.use('_mpl-gallery-nogrid')


# let us make data for our contour
X, Y = np.meshgrid([1, 2, 3, 4], [1, 2, 3, 4])
angle = np.pi / 180 * np.array([[15., 30, 35, 45], [25., 40, 55, 60], [35., 50, 65, 75], [45., 60, 75, 90]])

amplitude = np.array([[5, 10, 25, 50], [10, 15, 30, 60], [15, 26, 50, 70], [20, 45, 80, 100]])

U = amplitude * np.sin(angle)
V = amplitude * np.cos(angle)

# let us plot the barbs
fig, ax = plt.subplots()

ax.barbs(X, Y, U, V, barbcolor='C0',  flagcolor='C0', length=7, linewidth=1.5)


ax.set(xlim=(0, 4.5), ylim=(0, 4.5))

plt.show()

# %%
print(V)
# Out:
# [[4.82962913e+00 8.66025404e+00 2.04788011e+01 3.53553391e+01]
#  [9.06307787e+00 1.14906666e+01 1.72072931e+01 3.00000000e+01]
#  [1.22872807e+01 1.67124779e+01 2.11309131e+01 1.81173332e+01]
#  [1.41421356e+01 2.25000000e+01 2.07055236e+01 6.12323400e-15]]

# %% [markdown]
# ### quiver(X, Y, U, V)

# %%
plt.style.use('_mpl-gallery-nogrid')


# let us make data for our quiver
x = np.linspace(-4, 4, 6)
y = np.linspace(-4, 4, 6)

X, Y = np.meshgrid(x, y)

U = X + Y
V = Y - X

# let us plot quiver plot
fig, ax = plt.subplots()


ax.quiver(X, Y, U, V, color="C0", angles='xy', scale_units='xy', scale=5, width=0.015)

ax.set(xlim=(-5, 5), ylim=(-5, 5))

plt.show()

# %%
print(V)
# Out:
# [[4.82962913e+00 8.66025404e+00 2.04788011e+01 3.53553391e+01]
#  [9.06307787e+00 1.14906666e+01 1.72072931e+01 3.00000000e+01]
#  [1.22872807e+01 1.67124779e+01 2.11309131e+01 1.81173332e+01]
#  [1.41421356e+01 2.25000000e+01 2.07055236e+01 6.12323400e-15]]

# %%
V.ndim
# Out:
# 2

# %%
V.shape
# Out:
# (4, 4)

# %%
X.size
# Out:
# 36

# %% [markdown]
# ### streamplot(X, Y, U, V)

# %%
plt.style.use('_mpl-gallery-nogrid')

# make a stream function
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)

# let us make U and V out of the streamfunction:
V = np.diff(Z[1:, :], axis=1)
U = -np.diff(Z[:, 1:], axis=0)


# plot a streamplot
fig, ax = plt.subplots()

ax.streamplot(X[1:, 1:], Y[1:, 1:], U, V)
plt.show()

# %%
print(Z)
# Out:
# [[-4.07401958e-06 -4.52491734e-06 -5.01942805e-06 ...  3.97141851e-06
#    3.61338015e-06  3.28206063e-06]
#  [-4.67810834e-06 -5.19541902e-06 -5.76269208e-06 ...  4.58568650e-06
#    4.17168372e-06  3.78866978e-06]
#  [-5.36599501e-06 -5.95886771e-06 -6.60891625e-06 ...  5.28878750e-06
#    4.81064681e-06  4.36840125e-06]
#  ...
#  [-4.32809319e-06 -4.76425262e-06 -5.23544732e-06 ...  6.66225642e-06
#    6.00526190e-06  5.40630307e-06]
#  [-3.75361065e-06 -4.13133100e-06 -4.53929230e-06 ...  5.80908627e-06
#    5.23577174e-06  4.71316747e-06]
#  [-3.25160068e-06 -3.57832103e-06 -3.93111045e-06 ...  5.05973610e-06
#    4.55997646e-06  4.10447954e-06]]

# %%
Z.ndim
# Out:
# 2

# %%
import numpy as np
import matplotlib.pyplot as plt


w = 3
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2 + V**2)

fig, axs = plt.subplots(3, 2, figsize=(7, 9), height_ratios=[1, 1, 2])
axs = axs.flat

#  Varying density along a streamline
axs[0].streamplot(X, Y, U, V, density=[0.5, 1])
axs[0].set_title('Varying Density')

# Varying color along a streamline
strm = axs[1].streamplot(X, Y, U, V, color=U, linewidth=2, cmap='autumn')
fig.colorbar(strm.lines)
axs[1].set_title('Varying Color')

#  Varying line width along a streamline
lw = 5*speed / speed.max()
axs[2].streamplot(X, Y, U, V, density=0.6, color='k', linewidth=lw)
axs[2].set_title('Varying Line Width')

# Controlling the starting points of the streamlines
seed_points = np.array([[-2, -1, 0, 1, 2, -1], [-2, -1,  0, 1, 2, 2]])

strm = axs[3].streamplot(X, Y, U, V, color=U, linewidth=2,
                         cmap='autumn', start_points=seed_points.T)
fig.colorbar(strm.lines)
axs[3].set_title('Controlling Starting Points')

# Displaying the starting points with blue symbols.
axs[3].plot(seed_points[0], seed_points[1], 'bo')
axs[3].set(xlim=(-w, w), ylim=(-w, w))

# Create a mask
mask = np.zeros(U.shape, dtype=bool)
mask[40:60, 40:60] = True
U[:20, :20] = np.nan
U = np.ma.array(U, mask=mask)

axs[4].streamplot(X, Y, U, V, color='r')
axs[4].set_title('Streamplot with Masking')

axs[4].imshow(~mask, extent=(-w, w, -w, w), alpha=0.5, cmap='gray',
              aspect='auto')
axs[4].set_aspect('equal')

axs[5].streamplot(X, Y, U, V, broken_streamlines=False)
axs[5].set_title('Streamplot with unbroken streamlines')

plt.tight_layout()
plt.show()
